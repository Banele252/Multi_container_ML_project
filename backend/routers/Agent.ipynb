# %% [markdown]
# ### Build an AI agent
# - Agent should provide feedback based on the dataset shared
# - The A.I should call the ML model if it has predict an outcome that does not exist in the dataset
# - It should log the request, the outcome and if it used the model to answer the question or not
